# %% [markdown]
# # **Guided Lab - 344.4.3 - Python Seaborn Regression Plot**

# %% [markdown]
# ## **Lab Objective:**
# The objective of this lab is to familiarize participants with Seaborn's regression plot functionalities and how to utilize them effectively for data visualization and analysis. Participants will learn how to create various types of regression plots to explore relationships between variables, identify patterns, and visualize trends in their data.
#
#
# ## **Learning Objectives:**
#
# By the end of this lab, participants will be able to:
# - Describe the Seaborn's regression plot functionalities.
# - Apply Seaborn library to their own datasets for insightful data visualization.
#
# ## **Lab Introduction:**
#
# Regression plots, as the name suggests, are used to perform regression analysis between two or more variables.
#
# In this lab, we will explore Seaborn's regression plot capabilities, which are widely used for visualizing relationships between variables and for identifying trends in data. Regression plots provide a comprehensive way to understand the relationship between two or more variables, whether they exhibit a linear, non-linear, or categorical association. Through hands-on lab activities and examples, participants will learn how to create regression lines, and confidence intervals to analyze their datasets effectively.

# %% [markdown]
# ## **Dataset information:**
#
# The dataset that we are going to use for this section is the "diamonds" dataset, which is downloaded by default with the seaborn library.
#
# Execute the following script to load the dataset:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = sns.load_dataset('diamonds')

dataset.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# - The dataset contains different features of a diamond such as weight in carats, color, clarity, price, etc.
#
# - Let's plot a linear relationship between carat and price of the diamond. Ideally, the heavier the diamond is, the higher the price should be. Let's see if this is actually true based on the information available in the diamonds dataset.
#
# - To plot the linear model, the **`lmplot()`** function is used. The first parameter is the feature you want to plot on the `x-axis`, while the second variable is the feature you want to plot on the `y-axis`. The last parameter is the dataset. Execute the following script:

# %%
sns.lmplot(x='carat', y='price', height=7, aspect=3, data=dataset).set(title='Diamond')

# %% [markdown]
# You can also plot multiple linear models based on a categorical feature. The feature name is passed as value to the hue parameter.
#
# For instance, if you want to plot multiple linear models for the relationship between `carat` and `price` feature, based on the cut of the diamond, you can use lmplot() function as follows:

# %%
sns.lmplot(x='carat', y='price', height=7, aspect=3, data=dataset, hue='cut').set(title='Diamond')

# %% [markdown]
# From the output, you can see that the linear relationship between the carat and the price of the diamond is steepest for the ideal cut diamond as expected, and the linear model is shallowest for fair cut diamond.
#
# In addition to plotting the data for the cut feature with different hues, we can also have one plot for each cut. To do so, you need to pass the column name to the **`cols`** attribute. Take a look at the following script:

# %%
sns.lmplot(x='carat', y='price', data=dataset, col='cut')
# In the output, you will see a separate column for each value in the cut column of the diamonds dataset as shown below:

# %% [markdown]
# You can also change the size and aspect ratio of the plots using the `**height**` and `**aspect**` parameters. Take a look at the following script:

# %%
sns.lmplot(x='carat', y = 'price', data= dataset, col = 'cut', aspect = 0.5, height = 8 )

# %% [markdown]
# The **`aspect`** parameter defines the aspect ratio between the width and height. An aspect ratio of 0.5 means that the width is half of the height as shown in the output.
