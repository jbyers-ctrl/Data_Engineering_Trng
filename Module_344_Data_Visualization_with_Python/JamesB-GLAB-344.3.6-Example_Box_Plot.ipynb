# %% [markdown]
# # **Guided Lab - 344.3.6 - Example Box Plot!**

# %% [markdown]
# ## **Lab Overview:**
#
# In this lab, participants will explore the concept of box plots and their application in data visualization. The lab will begin with an introduction to box plots, explaining their components such as the box, whiskers, median, quartiles, and outliers. Participants will learn how to create box plots using Matplotlib's pyplot interface and how to customize various aspects of the plot, including colors, labels, and titles. This lab will cover scenarios such as comparing the distribution of exam scores across subjects.
#
# Throughout the lab, participants will gain practical experience in using Matplotlib to generate informative box plots, interpret the insights derived from these plots, and effectively communicate their findings.
#
# ## **Lab Objective:**
#  By the end of the lab, participants will be ale to:
#
# *   Describe how to leverage box plots for exploratory data analysis and statistical inference.
# *   Create box plots using Matplot.

# %% [markdown]
# **Overview of Box plot:**
# The term “box plot” refers to an outlier box plot; this plot is also called a box-and-whisker plot or a Tukey box plot.
#
# Here are the basic parts of a box plot:
#
# - The center line in the box shows the median for the data. Half of the data is above this value, and half is below. If the data are symmetrical, the median will be in the center of the box. If the data are skewed, the median will be closer to the top or to the bottom of the box.
# - The bottom and top of the box show the 25th and 75th quantiles, or percentiles. These two quantiles are also called quartiles because each cuts off a quarter (25%) of the data. The length of the box is the difference between these two percentiles and is called the interquartile range (IQR).
# - The lines that extend from the box are called whiskers. The whiskers represent the expected variation of the data. The whiskers extend 1.5 times the IQR from the top and bottom of the box. If the data do not extend to the end of the whiskers, then the whiskers extend to the minimum and maximum data values.
# - If there are values that fall above or below the end of the whiskers, they are plotted as dots. These points are often called outliers. An outlier is more extreme than the expected variation. These data points are worthy of review to determine if they are outliers or errors; the whiskers will not include these outliers.
#
# ![Box-Plot-Introduction-to-Statistics-JMP.png](data:image/png;base64,...)**

# %% [markdown]
# ## **Dataset for lab:**
#  We have a dataset of students' exam scores across different subjects to demonstrate the use of box plots for analysis.
#
# [ Click here for download the Dataset](https://drive.google.com/file/d/1Scyuy9a0fOhf9CPw2DSXOz_fx9gwPzPc/view?usp=sharing)

# %% [markdown]
# ### **Example 1: Create Simple Box Plot for Students' Exam Scores Across Analysis.**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the CSV file into a DataFrame
df = pd.read_csv('./Data/exam_scores.csv')

# Extract exam scores for each subject
math_scores = df['Math']
english_scores = df['English']
science_scores = df['Science']


#initializing the lables
labelName = ['Math', 'English', 'Science']
# Create a box plot

# 'labels' parameter of boxplot() has been renamed 'tick_labels'
plt.boxplot([math_scores, english_scores, science_scores], tick_labels=labelName, patch_artist=True)

# Add labels and title
plt.xlabel('Subjects')
plt.ylabel('Exam Scores')
plt.title('Distribution of Exam Scores Across Subjects')

# Add grid lines
plt.grid(True)

# Display the plot
plt.show()

# %% [markdown]
# ## **Example 2: Horizontal Box Plot**
# To create a horizontal boxplot, you need to set the vert argument to False:

# %%
# Load the CSV file into a DataFrame
# df = pd.read_csv('exam_scores.csv')

# Extract exam scores for each subject
math_scores = df['Math']
english_scores = df['English']
science_scores = df['Science']
#initializing the lables
labelName = ['Math', 'English', 'Science']
# Create a box plot

plt.boxplot([math_scores, english_scores, science_scores],
            tick_labels=labelName,
            patch_artist=True,
            vert=False)

# Add labels and title
plt.ylabel('Subjects')
plt.xlabel('Exam Scores')
plt.title('Distribution of Exam Scores Across Subjects')

# Add grid lines
plt.grid(True)

# Display the plot
plt.show()

# %%
# Load the CSV file into a DataFrame
df = pd.read_csv('./Data/exam_scores.csv')

# Extract exam scores for each subject
math_scores = df['Math']
english_scores = df['English']
science_scores = df['Science']


#initializing the lables
labelName = ['Math', 'English', 'Science']
# Create a box plot

#                                                                                Show outliers beyond the caps
plt.boxplot([math_scores, english_scores, science_scores], tick_labels=labelName, showfliers=False)

# Add labels and title
plt.xlabel('Subjects')
plt.ylabel('Exam Scores')
plt.title('Distribution of Exam Scores Across Subjects')

# Add grid lines
plt.grid(True)

# Display the plot
plt.show()
